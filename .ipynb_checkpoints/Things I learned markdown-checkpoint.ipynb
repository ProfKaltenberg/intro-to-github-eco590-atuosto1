# %% [markdown]
# I learned how to open up a branch and how to save things to my repository
#
# I am still honestly a little confused on the operational parts of github work but I really think as I use it more i'll get more comfortable with it.
